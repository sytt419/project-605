# %% [markdown]
# # title: "Global Terrorism Attacks Project 605"
# author: "Jois Xie"

# %%
import pathlib
from setuptools import setup

# The directory containing this file
HERE = pathlib.Path(project605).parent

# The text of the README file
README = (HERE / "README.md").read_text()

# This call to setup() does all the work
setup(
    name="realpython-reader",
    version="1.0.0",
    description="Read the latest Real Python tutorials",
    long_description=README,
    long_description_content_type="text/markdown",
    url="https://github.com/realpython/reader",
    author="Real Python",
    author_email="office@realpython.com",
    license="MIT",
    classifiers=[
        "License :: OSI Approved :: MIT License",
        "Programming Language :: Python :: 3",
        "Programming Language :: Python :: 3.7",
    ],
    packages=["reader"],
    include_package_data=True,
    install_requires=["feedparser", "html2text"],
    entry_points={
        "console_scripts": [
            "realpython=reader.__main__:main",
        ]
    },
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-207-e66765f9ee17> in <module>()
#       3
#       4 # The directory containing this file
# ----> 5 HERE = pathlib.Path(project605).parent
#       6
#       7 # The text of the README file
#
# NameError: name 'project605' is not defined

# %%
## Get the imports out of the way
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns

import plotly
import plotly.plotly as py
plotly.tools.set_credentials_file(username='srveale', api_key='GajxMbxLyoAc3R0I6K6e')
import plotly.graph_objs as go
from plotly import tools
# import plotly.offline as py

import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.style.use('ggplot')
import matplotlib.dates as mdates
from matplotlib import dates
from matplotlib.lines import Line2D
from datetime import datetime
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# '/Users/siyuxie/Desktop'

# %%
os.chdir('/Users/siyuxie/desktop')

# %%
## Read in the raw data
#raw = pd.read_csv('605project.csv', 'r', encoding='mac_roman')
raw = pd.read_csv("605project.csv", encoding='latin-1')

# %% [markdown]
# # Q1. What is the trend of total number of terrorists happen each year from 1970 to 2017? Which year has the highest attack?
#
# The total number of terrorists increase from 1970 to 2017, 2014 has the highest number of attacks among those years.

# %%
plt.subplots(figsize=(15,6))
sns.countplot('iyear',data=raw,palette='RdYlGn_r',edgecolor=sns.color_palette('dark',7))
plt.xticks(rotation=90)
plt.title('Number Of Terrorist Activities Each Year')
plt.show()

# %%
terror_region=pd.crosstab(raw.iyear,raw.region_txt)
terror_region.plot(color=sns.color_palette('Set2',12))
fig=plt.gcf()
fig.set_size_inches(18,6)
plt.show()

# %%
terror_region=pd.crosstab(raw.iyear,raw.weaptype1_txt)
terror_region.plot(color=sns.color_palette('Set2',12))
fig=plt.gcf()
fig.set_size_inches(18,6)
plt.show()

# %% [markdown]
# # Q1. What amount of total attacks for each country from 1970 to 2017? Which country has the highest number and which country has the lowest?

# %%
column_list = raw.columns.values.tolist()
column_list
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'country',
#  'country_txt',
#  'region',
#  'region_txt',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'location',
#  'summary',
#  'attacktype1_txt',
#  'targtype1',
#  'targtype1_txt',
#  'natlty1',
#  'natlty1_txt',
#  'gname',
#  'motive',
#  'weaptype1_txt',
#  'weapdetail',
#  'propextent_txt',
#  'propvalue',
#  'propcomment',
#  'addnotes',
#  'dbsource']

# %%
raw['country_txt'].unique()
# Out:
# array(['Dominican Republic', 'Mexico', 'Philippines', 'Greece', 'Japan',
#        'United States', 'Uruguay', 'Italy', 'East Germany (GDR)',
#        'Ethiopia', 'Guatemala', 'Venezuela', 'West Germany (FRG)',
#        'Switzerland', 'Jordan', 'Spain', 'Brazil', 'Egypt', 'Argentina',
#        'Lebanon', 'Ireland', 'Turkey', 'Paraguay', 'Iran',
#        'United Kingdom', 'Colombia', 'Bolivia', 'Nicaragua',
#        'Netherlands', 'Belgium', 'Canada', 'Australia', 'Pakistan',
#        'Zambia', 'Sweden', 'Costa Rica', 'South Yemen', 'Cambodia',
#        'Israel', 'Poland', 'Taiwan', 'Panama', 'Kuwait',
#        'West Bank and Gaza Strip', 'Austria', 'Czechoslovakia', 'India',
#        'France', 'South Vietnam', 'Brunei', 'Zaire',
#        "People's Republic of the Congo", 'Portugal', 'Algeria',
#        'El Salvador', 'Thailand', 'Haiti', 'Sudan', 'Morocco', 'Cyprus',
#        'Myanmar', 'Afghanistan', 'Peru', 'Chile', 'Honduras',
#        'Yugoslavia', 'Ecuador', 'New Zealand', 'Malaysia', 'Singapore',
#        'Botswana', 'Jamaica', 'Chad', 'North Yemen', 'Andorra', 'Syria',
#        'South Korea', 'United Arab Emirates', 'South Africa', 'Kenya',
#        'Iraq', 'Somalia', 'Tanzania', 'Sri Lanka', 'Namibia', 'Bahamas',
#        'Nigeria', 'Barbados', 'Trinidad and Tobago', 'Bangladesh',
#        'Angola', 'Mauritania', 'Saudi Arabia', 'Djibouti', 'Indonesia',
#        'Malta', 'Rhodesia', 'Soviet Union', 'Denmark', 'Western Sahara',
#        'Guyana', 'Mozambique', 'Tunisia', 'Uganda', 'Norway', 'Lesotho',
#        'Gabon', 'Libya', 'Bahrain', 'Hong Kong', 'Senegal', 'Zimbabwe',
#        'Guinea', 'Grenada', 'New Hebrides', 'Belize', 'Guadeloupe',
#        'Martinique', 'Vatican City', 'Albania',
#        'Central African Republic', 'Seychelles', 'Dominica', 'Qatar',
#        'Bulgaria', 'Suriname', 'Swaziland', 'Luxembourg', 'Iceland',
#        'French Guiana', 'Falkland Islands', 'Burkina Faso',
#        'New Caledonia', 'Romania', 'Niger', 'Nepal', 'Togo', 'Finland',
#        'Fiji', 'Ghana', 'Maldives', 'Mauritius', 'Hungary', 'Laos',
#        'Papua New Guinea', 'China', 'Liberia', 'Republic of the Congo',
#        'Mali', 'Germany', 'Yemen', 'Rwanda', 'Sierra Leone', 'Cameroon',
#        'Cuba', 'Croatia', 'Georgia', 'Azerbaijan', 'Madagascar',
#        'Lithuania', 'Burundi', 'Ukraine', 'Moldova', 'Armenia', 'Russia',
#        'Ivory Coast', 'Kazakhstan', 'Antigua and Barbuda',
#        'Bosnia-Herzegovina', 'Equatorial Guinea', 'Tajikistan', 'Malawi',
#        'Uzbekistan', 'Latvia', 'Estonia', 'Vietnam', 'Comoros', 'Benin',
#        'Slovak Republic', 'Macedonia', 'Wallis and Futuna', 'Belarus',
#        'Czech Republic', 'Slovenia', 'Gambia', 'North Korea', 'Eritrea',
#        'St. Kitts and Nevis', 'French Polynesia', 'Macau', 'Kyrgyzstan',
#        'Vanuatu', 'Democratic Republic of the Congo', 'Kosovo',
#        'Solomon Islands', 'East Timor', 'St. Lucia', 'Guinea-Bissau',
#        'Montenegro', 'International', 'Turkmenistan', 'Serbia-Montenegro',
#        'Bhutan', 'Serbia', 'South Sudan'], dtype=object)

# %%
# for american countries
america = raw[raw.country_txt == 'United States']
america
#america <- subset(raw, Product = p.id & Month < mn & Year == yr, select = c(Time, Product))
# Out:
#              eventid  iyear  imonth  iday  country    country_txt  region  \
# 5       1.970010e+11   1970       1     1      217  United States       1
# 7       1.970010e+11   1970       1     2      217  United States       1
# 8       1.970010e+11   1970       1     2      217  United States       1
# 9       1.970010e+11   1970       1     3      217  United States       1
# 10      1.970010e+11   1970       1     1      217  United States       1
# 11      1.970010e+11   1970       1     6      217  United States       1
# 13      1.970010e+11   1970       1     9      217  United States       1
# 14      1.970010e+11   1970       1     9      217  United States       1
# 17      1.970010e+11   1970       1    12      217  United States       1
# 18      1.970010e+11   1970       1    12      217  United States       1
# 19      1.970010e+11   1970       1    13      217  United States       1
# 20      1.970010e+11   1970       1    14      217  United States       1
# 22      1.970010e+11   1970       1    19      217  United States       1
# 23      1.970010e+11   1970       1    19      217  United States       1
# 24      1.970010e+11   1970       1    19      217  United States       1
# 28      1.970010e+11   1970       1    22      217  United States       1
# 29      1.970010e+11   1970       1    25      217  United States       1
# 30      1.970010e+11   1970       1    25      217  United States       1
# 31      1.970010e+11   1970       1    26      217  United States       1
# 32      1.970010e+11   1970       1    26      217  United States       1
# 33      1.970010e+11   1970       1    27      217  United States       1
# 35      1.970010e+11   1970       1    28      217  United States       1
# 36      1.970010e+11   1970       1    30      217  United States       1
# 37      1.970010e+11   1970       1    30      217  United States       1
# 38      1.970010e+11   1970       1    30      217  United States       1
# 40      1.970010e+11   1970       1    31      217  United States       1
# 41      1.970020e+11   1970       2     1      217  United States       1
# 42      1.970020e+11   1970       2     1      217  United States       1
# 43      1.970020e+11   1970       2     2      217  United States       1
# 44      1.970020e+11   1970       2     3      217  United States       1
# ...              ...    ...     ...   ...      ...            ...     ...
# 175737  2.017060e+11   2017       6     9      217  United States       1
# 175914  2.017060e+11   2017       6    14      217  United States       1
# 176194  2.017060e+11   2017       6    21      217  United States       1
# 176364  2.017060e+11   2017       6    26      217  United States       1
# 176685  2.017070e+11   2017       7     5      217  United States       1
# 176735  2.017070e+11   2017       7     7      217  United States       1
# 176758  2.017070e+11   2017       7     8      217  United States       1
# 176804  2.017070e+11   2017       7     9      217  United States       1
# 176949  2.017070e+11   2017       7    13      217  United States       1
# 177647  2.017080e+11   2017       8     4      217  United States       1
# 177655  2.017080e+11   2017       8     5      217  United States       1
# 177863  2.017080e+11   2017       8    12      217  United States       1
# 178079  2.017080e+11   2017       8    19      217  United States       1
# 178776  2.017090e+11   2017       9    11      217  United States       1
# 178798  2.017090e+11   2017       9    12      217  United States       1
# 178858  2.017090e+11   2017       9    14      217  United States       1
# 179098  2.017090e+11   2017       9    24      217  United States       1
# 179344  2.017100e+11   2017      10     1      217  United States       1
# 179474  2.017100e+11   2017      10     6      217  United States       1
# 179522  2.017100e+11   2017      10     8      217  United States       1
# 179912  2.017100e+11   2017      10    22      217  United States       1
# 180052  2.017100e+11   2017      10    28      217  United States       1
# 180118  2.017100e+11   2017      10    31      217  United States       1
# 180135  2.017100e+11   2017      10    31      217  United States       1
# 180304  2.017110e+11   2017      11     7      217  United States       1
# 180461  2.017110e+11   2017      11    13      217  United States       1
# 181141  2.017120e+11   2017      12     7      217  United States       1
# 181219  2.017120e+11   2017      12    11      217  United States       1
# 181478  2.017120e+11   2017      12    22      217  United States       1
# 181479  2.017120e+11   2017      12    22      217  United States       1
#
#            region_txt       provstate              city  \
# 5       North America        Illinois             Cairo
# 7       North America      California           Oakland
# 8       North America       Wisconsin           Madison
# 9       North America       Wisconsin           Madison
# 10      North America       Wisconsin           Baraboo
# 11      North America        Colorado            Denver
# 13      North America        Michigan           Detroit
# 14      North America     Puerto Rico       Rio Piedras
# 17      North America        New York     New York City
# 18      North America     Puerto Rico        Rio Grande
# 19      North America      Washington           Seattle
# 20      North America        Illinois         Champaign
# 22      North America      Washington           Seattle
# 23      North America      Washington           Seattle
# 24      North America      New Jersey       Jersey City
# 28      North America        Nebraska  South Sioux City
# 29      North America     Mississippi        West Point
# 30      North America        New York     New York City
# 31      North America     Mississippi        West Point
# 32      North America        New York     New York City
# 33      North America            Ohio           Norwalk
# 35      North America      Washington           Seattle
# 36      North America        Nebraska  South Sioux City
# 37      North America        Nebraska  South Sioux City
# 38      North America         Florida      Coral Gables
# 40      North America        Colorado            Denver
# 41      North America          Oregon          Portland
# 42      North America        Illinois             Cairo
# 43      North America        New York     New York City
# 44      North America        New York     New York City
# ...               ...             ...               ...
# 175737  North America        New York     New York City
# 175914  North America        Virginia        Alexandria
# 176194  North America        Michigan             Flint
# 176364  North America        New York     New York City
# 176685  North America        New York             Bronx
# 176735  North America           Texas            Dallas
# 176758  North America         Indiana          Columbus
# 176804  North America    Pennsylvania      Campbelltown
# 176949  North America    Pennsylvania      Campbelltown
# 177647  North America        Missouri       Kansas City
# 177655  North America       Minnesota       Bloomington
# 177863  North America        Virginia   Charlottesville
# 178079  North America           Texas           Houston
# 178776  North America       Louisiana       Baton Rouge
# 178798  North America       Louisiana       Baton Rouge
# 178858  North America       Louisiana       Baton Rouge
# 179098  North America       Tennessee           Antioch
# 179344  North America          Nevada         Las Vegas
# 179474  North America  North Carolina          Fletcher
# 179522  North America      Washington           Spokane
# 179912  North America        Nebraska            Oxford
# 180052  North America     Puerto Rico          San Juan
# 180118  North America        New York     New York City
# 180135  North America       Louisiana   Richland Parish
# 180304  North America        Illinois         Champaign
# 180461  North America  North Carolina              Vale
# 181141  North America      New Mexico             Aztec
# 181219  North America        New York     New York City
# 181478  North America    Pennsylvania        Harrisburg
# 181479  North America    Pennsylvania        Harrisburg
#
#                   ...               natlty1_txt  \
# 5                 ...             United States
# 7                 ...             United States
# 8                 ...             United States
# 9                 ...             United States
# 10                ...             United States
# 11                ...             United States
# 13                ...             United States
# 14                ...             United States
# 17                ...             United States
# 18                ...             United States
# 19                ...             United States
# 20                ...             United States
# 22                ...             United States
# 23                ...             United States
# 24                ...             United States
# 28                ...             United States
# 29                ...             United States
# 30                ...             United States
# 31                ...             United States
# 32                ...             United States
# 33                ...             United States
# 35                ...             United States
# 36                ...             United States
# 37                ...             United States
# 38                ...             United States
# 40                ...             United States
# 41                ...             United States
# 42                ...             United States
# 43                ...             United States
# 44                ...             United States
# ...               ...                       ...
# 175737            ...             United States
# 175914            ...             United States
# 176194            ...             United States
# 176364            ...             United States
# 176685            ...             United States
# 176735            ...             United States
# 176758            ...             United States
# 176804            ...             United States
# 176949            ...             United States
# 177647            ...             United States
# 177655            ...             United States
# 177863            ...             United States
# 178079            ...             United States
# 178776            ...             United States
# 178798            ...             United States
# 178858            ...             United States
# 179098            ...             United States
# 179344            ...             United States
# 179474            ...             United States
# 179522            ...             United States
# 179912            ...             United States
# 180052            ...             United States
# 180118            ...                 Argentina
# 180135            ...             United States
# 180304            ...             United States
# 180461            ...             United States
# 181141            ...             United States
# 181219            ...             United States
# 181478            ...             United States
# 181479            ...             United States
#
#                                                     gname  \
# 5                                      Black Nationalists
# 7                                                 Unknown
# 8                                         New Year's Gang
# 9                                         New Year's Gang
# 10                        Weather Underground, Weathermen
# 11                                    Left-Wing Militants
# 13                                    Left-Wing Militants
# 14                          Armed Commandos of Liberation
# 17                                     Black Nationalists
# 18                                               Strikers
# 19                                     Black Nationalists
# 20                                     Black Nationalists
# 22                                     Black Nationalists
# 23                                       Student Radicals
# 24                                       White extremists
# 28                                               Strikers
# 29                                       White extremists
# 30                                     Black Nationalists
# 31                                     Black Nationalists
# 32                                     Black Nationalists
# 33                                    Left-Wing Militants
# 35                                       White extremists
# 36                                               Strikers
# 37                                               Strikers
# 38                                       Student Radicals
# 40                                                Unknown
# 41                                    Left-Wing Militants
# 42                                     Black Nationalists
# 43                                                Unknown
# 44                                                Unknown
# ...                                                   ...
# 175737                             Anti-Muslim extremists
# 175914                         Anti-Republican extremists
# 176194                         Anti-Government extremists
# 176364                            Anti-Semitic extremists
# 176685                             Anti-Police extremists
# 176735                               Anti-LGBT extremists
# 176758                                            Unknown
# 176804                                  Environmentalists
# 176949                                  Environmentalists
# 177647                                            Unknown
# 177655  White Rabbit Three Percent Illinois Patriot Fr...
# 177863                                Neo-Nazi extremists
# 178079                                            Unknown
# 178776                                   White extremists
# 178798                                   White extremists
# 178858                                   White extremists
# 179098                                            Unknown
# 179344                         Anti-Government extremists
# 179474                                            Unknown
# 179522                                   White extremists
# 179912                                   White extremists
# 180052                               Anti-LGBT extremists
# 180118                         Jihadi-inspired extremists
# 180135                                   White extremists
# 180304  White Rabbit Three Percent Illinois Patriot Fr...
# 180461                         Pro-LGBT Rights extremists
# 181141                                   White extremists
# 181219                         Jihadi-inspired extremists
# 181478                                            Unknown
# 181479                                            Unknown
#
#                                                    motive  \
# 5          To protest the Cairo Illinois Police Deparment
# 7                                                     NaN
# 8             To protest the War in Vietnam and the draft
# 9             To protest the War in Vietnam and the draft
# 10                                                    NaN
# 11                      Protest the draft and Vietnam War
# 13                                                    NaN
# 14      To protest United States owned businesses in P...
# 17      Suspected motives were to protest the Vietnam ...
# 18                                                    NaN
# 19      Retaliation for the store owner who shot and k...
# 20                                                    NaN
# 22      The incident took place during disturbances be...
# 23      The incident took place during heightened anti...
# 24                    Intimidate the Black Panther Party.
# 28      The attack occurred during the violent Iowa Be...
# 29      The motive of the attack was to prevent the Af...
# 30                                         To kill police
# 31      African American opposition to the school inte...
# 32                                         To kill police
# 33                         Protest and sabotage the draft
# 35                                                    NaN
# 36      The attack occurred during the violent Iowa Be...
# 37      The attack occurred during the violent Iowa Be...
# 38      To protest the R.O.T.C. program and the War in...
# 40                                                    NaN
# 41                         Protest and sabotage the draft
# 42           To protest police presence in Pyramid Courts
# 43                                                    NaN
# 44                                                    NaN
# ...                                                   ...
# 175737                                                NaN
# 175914  The specific motive is unknown; however, sourc...
# 176194  An unaffiliated individual, identified as Amor...
# 176364  The specific motive is unknown; however, sourc...
# 176685  The specific motive is unknown; however, sourc...
# 176735                                                NaN
# 176758                                                NaN
# 176804                                                NaN
# 176949                                                NaN
# 177647                                                NaN
# 177655                                                NaN
# 177863                                                NaN
# 178079  The specific motive is unknown; however, sourc...
# 178776  The specific motive is unknown; however, sourc...
# 178798  The specific motive is unknown; however, sourc...
# 178858  The specific motive is unknown; however, sourc...
# 179098  An unaffiliated individual, identified as Eman...
# 179344                                                NaN
# 179474  An unaffiliated individual, identified as Mich...
# 179522  Two unaffiliated individuals, identified as Ja...
# 179912  The specific motive is unknown; however, sourc...
# 180052                                                NaN
# 180118  An unaffiliated individual, identified as Sayf...
# 180135                                                NaN
# 180304                                                NaN
# 180461  Pro-LGBT Rights extremists claimed responsibil...
# 181141  An unaffiliated individual, identified as Will...
# 181219  An unaffiliated individual, identified as Akay...
# 181478                                                NaN
# 181479                                                NaN
#
#                                             weaptype1_txt  \
# 5                                                Firearms
# 7                                              Explosives
# 8                                              Incendiary
# 9                                              Incendiary
# 10                                             Explosives
# 11                                             Incendiary
# 13                                             Incendiary
# 14                                             Incendiary
# 17                                             Explosives
# 18                                             Explosives
# 19                                             Incendiary
# 20                                             Incendiary
# 22                                             Explosives
# 23                                             Explosives
# 24                                             Incendiary
# 28                                             Explosives
# 29                                             Incendiary
# 30                                               Firearms
# 31                                             Explosives
# 32                                               Firearms
# 33                                             Incendiary
# 35                                             Explosives
# 36                                             Explosives
# 37                                             Explosives
# 38                                             Incendiary
# 40                                             Explosives
# 41                                             Incendiary
# 42                                               Firearms
# 43                                             Incendiary
# 44                                             Incendiary
# ...                                                   ...
# 175737                                           Firearms
# 175914                                           Firearms
# 176194                                              Melee
# 176364                                         Incendiary
# 176685                                           Firearms
# 176735                                         Incendiary
# 176758                                         Incendiary
# 176804                                         Incendiary
# 176949                                         Incendiary
# 177647                                           Chemical
# 177655                                         Explosives
# 177863  Vehicle (not to include vehicle-borne explosiv...
# 178079                                         Explosives
# 178776                                           Firearms
# 178798                                           Firearms
# 178858                                           Firearms
# 179098                                           Firearms
# 179344                                           Firearms
# 179474                                         Explosives
# 179522                                           Firearms
# 179912                                           Firearms
# 180052                                         Incendiary
# 180118  Vehicle (not to include vehicle-borne explosiv...
# 180135                                         Incendiary
# 180304                                         Explosives
# 180461                                         Incendiary
# 181141                                           Firearms
# 181219                                         Explosives
# 181478                                           Firearms
# 181479                                           Firearms
#
#                                                weapdetail  \
# 5                            Several gunshots were fired.
# 7                                                     NaN
# 8                         Firebomb consisting of gasoline
# 9       Poured gasoline on the floor and lit it with a...
# 10                                              Explosive
# 11                                       Molotov cocktail
# 13                                               Firebomb
# 14                              Fire set in back of store
# 17      Crudely made pipe bomb.  Five inches long and ...
# 18                                                   Bomb
# 19                                               Firebomb
# 20                         Firebomb thrown through window
# 22                                                    NaN
# 23                                                    NaN
# 24      Gasoline was placed on the steps of the buildi...
# 28                  Dynamite thrown at foundation of home
# 29                                                    NaN
# 30      Nine thirty-caliber cartridges from a carbine ...
# 31      Several sticks of dynamite were thrown, from a...
# 32                                                    NaN
# 33                                                    NaN
# 35                                                    NaN
# 36                                               Dynamite
# 37                                               Dynamite
# 38      Two firebombs ignited, at least one of them wa...
# 40                              Suspected use of dynamite
# 41                             Fire started with gasoline
# 42                          High-powered rifle or carbine
# 43                                      Incendiary device
# 44      Incendiary device packed in a cigarette box th...
# ...                                                   ...
# 175737               A pellet gun was used in the attack.
# 175914  A 7.62-mm SKS semiautomatic rifle and a 9-mm h...
# 176194            A 12-inch knife was used in the attack.
# 176364                                                NaN
# 176685       A Ruger .38 revolver was used in the attack.
# 176735                                                NaN
# 176758                                                NaN
# 176804                                                NaN
# 176949                                                NaN
# 177647  An unidentified toxic substance, which smelled...
# 177655  A PVC pipe bomb containing black powder and di...
# 177863  A silver Dodge Challenger was used in the attack.
# 178079  A homemade explosive device was used in the at...
# 178776                                                NaN
# 178798                                                NaN
# 178858                                                NaN
# 179098                   A pistol was used in the attack.
# 179344  AR-15 semiautomatic rifles equipped with bump ...
# 179474  A timed homemade explosive device containing a...
# 179522                   A pistol was used in the attack.
# 179912  A .38-caliber handgun and a knife were used in...
# 180052              Petrol bombs were used in the attack.
# 180118  A rental pickup truck and replica firearms wer...
# 180135                   Gasoline was used in the attack.
# 180304  A PVC pipe bomb containing thermite and a magn...
# 180461                                                NaN
# 181141       A 9-mm Glock handgun was used in the attack.
# 181219  A crude pipe bomb consisting of screws,  Chris...
# 181478         Two 9-mm handguns were used in the attack.
# 181479         Two 9-mm handguns were used in the attack.
#
#                                        propextent_txt  propvalue  \
# 5                         Minor (likely < $1 million)        NaN
# 7                         Minor (likely < $1 million)    22500.0
# 8                         Minor (likely < $1 million)    60000.0
# 9                         Minor (likely < $1 million)        NaN
# 10                        Minor (likely < $1 million)        0.0
# 11                        Minor (likely < $1 million)      305.0
# 13                        Minor (likely < $1 million)        NaN
# 14      Major (likely >= $1 million but < $1 billion)  2000000.0
# 17                        Minor (likely < $1 million)        NaN
# 18                                            Unknown        NaN
# 19                        Minor (likely < $1 million)    17000.0
# 20                        Minor (likely < $1 million)        NaN
# 22                        Minor (likely < $1 million)     2200.0
# 23                                                NaN        NaN
# 24                        Minor (likely < $1 million)        NaN
# 28                        Minor (likely < $1 million)        NaN
# 29                        Minor (likely < $1 million)        NaN
# 30                        Minor (likely < $1 million)        NaN
# 31                        Minor (likely < $1 million)        NaN
# 32                                                NaN        NaN
# 33                        Minor (likely < $1 million)     8800.0
# 35                        Minor (likely < $1 million)     3000.0
# 36                        Minor (likely < $1 million)        NaN
# 37                        Minor (likely < $1 million)     2500.0
# 38                        Minor (likely < $1 million)        NaN
# 40                        Minor (likely < $1 million)        NaN
# 41                        Minor (likely < $1 million)     4189.0
# 42                        Minor (likely < $1 million)        NaN
# 43                                                NaN        NaN
# 44                                                NaN        NaN
# ...                                               ...        ...
# 175737                    Minor (likely < $1 million)      -99.0
# 175914                                            NaN        NaN
# 176194                                            NaN        NaN
# 176364                    Minor (likely < $1 million)      -99.0
# 176685                                            NaN        NaN
# 176735                    Minor (likely < $1 million)      -99.0
# 176758                    Minor (likely < $1 million)      -99.0
# 176804                    Minor (likely < $1 million)      -99.0
# 176949                    Minor (likely < $1 million)      -99.0
# 177647                                            NaN        NaN
# 177655                    Minor (likely < $1 million)      -99.0
# 177863                    Minor (likely < $1 million)      -99.0
# 178079                                            NaN        NaN
# 178776                    Minor (likely < $1 million)      -99.0
# 178798                                            NaN        NaN
# 178858                                            NaN        NaN
# 179098                                            NaN        NaN
# 179344                                        Unknown      -99.0
# 179474                                            NaN        NaN
# 179522                    Minor (likely < $1 million)      -99.0
# 179912                                            NaN        NaN
# 180052                    Minor (likely < $1 million)      -99.0
# 180118                    Minor (likely < $1 million)      -99.0
# 180135                    Minor (likely < $1 million)      -99.0
# 180304                    Minor (likely < $1 million)      -99.0
# 180461                    Minor (likely < $1 million)      -99.0
# 181141                    Minor (likely < $1 million)      -99.0
# 181219                                            NaN        NaN
# 181478                    Minor (likely < $1 million)      -99.0
# 181479                    Minor (likely < $1 million)      -99.0
#
#                                               propcomment  \
# 5                                                     NaN
# 7                        Three transformers were damaged.
# 8       Basketball courts, weight room, swimming pool,...
# 9                                           Slight damage
# 10                                                    NaN
# 11                                                    NaN
# 13                                   Building was damaged
# 14                                        Store destroyed
# 17      Damaged a blackboard and shattered a pane of g...
# 18                                                    NaN
# 19                                                    NaN
# 20                                                    NaN
# 22      Windows were shattered at the Liberal Arts and...
# 23                                                    NaN
# 24      The fire caused minor damages to the door and ...
# 28           Sizable hole in the house and broken windows
# 29                                    Building burnt down
# 30                     One window in a building shattered
# 31                                      Windows shattered
# 32                                                    NaN
# 33                                           Smoke damage
# 35                                 Small hole in the door
# 36                         Damaged foundation of building
# 37                                                    NaN
# 38                     Army personnel carrier was damaged
# 40                                       Restroom damaged
# 41      Approximately two hundred and fifty draft reco...
# 42                     Windshield of police car shattered
# 43                                                    NaN
# 44                                                    NaN
# ...                                                   ...
# 175737               A window was damaged in this attack.
# 175914                                                NaN
# 176194                                                NaN
# 176364                  A bus was damaged in this attack.
# 176685                                                NaN
# 176735  An LGBT community resource center was damaged ...
# 176758               A church was damaged in this attack.
# 176804      A portable toilet was damaged in this attack.
# 176949      A portable toilet was damaged in this attack.
# 177647                                                NaN
# 177655      An Islamic center was damaged in this attack.
# 177863              A vehicle was damaged in this attack.
# 178079                                                NaN
# 178776   A door and a window were damaged in this attack.
# 178798                                                NaN
# 178858                                                NaN
# 179098                                                NaN
# 179344  A hotel window and other unspecified property ...
# 179474                                                NaN
# 179522                A house was damaged in this attack.
# 179912                                                NaN
# 180052                  A bar was damaged in this attack.
# 180118           A school bus was damaged in this attack.
# 180135               A church was damaged in this attack.
# 180304               A window was damaged in this attack.
# 180461               A church was damaged in this attack.
# 181141       A classroom wall was damaged in this attack.
# 181219                                                NaN
# 181478              A vehicle was damaged in this attack.
# 181479              A vehicle was damaged in this attack.
#
#                                                  addnotes  \
# 5       The Cairo Chief of Police, William Petersen, r...
# 7       Damages were estimated to be between $20,000-$...
# 8       The New Years Gang issue a communiqu to a loc...
# 9       Karl Armstrong's girlfriend, Lynn Schultz, dro...
# 10                                                    NaN
# 11                                                    NaN
# 13                                                    NaN
# 14      The fire began at 8:30 PM. The Armed Commandos...
# 17      One half hour after the bomb explosion, an ano...
# 18                                                    NaN
# 19      The store was a White owned business operating...
# 20                                                    NaN
# 22      Witnesses observed three African American male...
# 23      Judith and Silas Bissell were both members of ...
# 24      The building might have been shot at a second ...
# 28      This attack might be linked with other episode...
# 29      Police, at the time suspected, that this attac...
# 30      Police do not believe that this attack was rel...
# 31      Police, at the time, suspected that this attac...
# 32      Police do not believe that this attack was rel...
# 33      The perpetrators broke through the door of the...
# 35                                                    NaN
# 36      This incident might be part of a multiple atta...
# 37      This incident might be part of a multiple atta...
# 38                                                    NaN
# 40                                                    NaN
# 41      It is suspected that the perpetrator was attem...
# 42      This attack took place during heightened racia...
# 43                                                    NaN
# 44      Part of a multiple attack with 197002030002.  ...
# ...                                                   ...
# 175737            The victims included Mahamadou Gumaneh.
# 175914  The victims included David Bailey, Crystal Gri...
# 176194                                                NaN
# 176364                                                NaN
# 176685  There is doubt that this incident meets terror...
# 176735                                                NaN
# 176758                                                NaN
# 176804                                                NaN
# 176949                                                NaN
# 177647                                                NaN
# 177655                                                NaN
# 177863                                                NaN
# 178079                                                NaN
# 178776  Gleeson was charged with two similar incidents...
# 178798  Gleeson was charged with two similar incidents...
# 178858  Gleeson was charged with two similar incidents...
# 179098  The victims included Melanie Smith, Robert Eng...
# 179344  Amaq News Agency, the Islamic State of Iraq an...
# 179474                                                NaN
# 179522                                                NaN
# 179912                                                NaN
# 180052  There is doubt that this incident meets terror...
# 180118  The victims included tourists from Argentina a...
# 180135                                                NaN
# 180304                                                NaN
# 180461                                                NaN
# 181141  The victims included students Casey Jordan Mar...
# 181219                                                NaN
# 181478  There is doubt that this incident meets terror...
# 181479  There is doubt that this incident meets terror...
#
#                         dbsource
# 5                 Hewitt Project
# 7                 Hewitt Project
# 8                 Hewitt Project
# 9                 Hewitt Project
# 10                          PGIS
# 11                Hewitt Project
# 13                Hewitt Project
# 14                Hewitt Project
# 17                Hewitt Project
# 18                Hewitt Project
# 19                Hewitt Project
# 20                Hewitt Project
# 22                Hewitt Project
# 23                Hewitt Project
# 24                Hewitt Project
# 28                Hewitt Project
# 29                Hewitt Project
# 30                Hewitt Project
# 31                Hewitt Project
# 32                Hewitt Project
# 33                Hewitt Project
# 35                Hewitt Project
# 36                Hewitt Project
# 37                Hewitt Project
# 38                Hewitt Project
# 40                Hewitt Project
# 41                Hewitt Project
# 42                Hewitt Project
# 43                Hewitt Project
# 44                Hewitt Project
# ...                          ...
# 175737  START Primary Collection
# 175914  START Primary Collection
# 176194  START Primary Collection
# 176364  START Primary Collection
# 176685  START Primary Collection
# 176735  START Primary Collection
# 176758  START Primary Collection
# 176804  START Primary Collection
# 176949  START Primary Collection
# 177647  START Primary Collection
# 177655  START Primary Collection
# 177863  START Primary Collection
# 178079  START Primary Collection
# 178776  START Primary Collection
# 178798  START Primary Collection
# 178858  START Primary Collection
# 179098  START Primary Collection
# 179344  START Primary Collection
# 179474  START Primary Collection
# 179522  START Primary Collection
# 179912  START Primary Collection
# 180052  START Primary Collection
# 180118  START Primary Collection
# 180135  START Primary Collection
# 180304  START Primary Collection
# 180461  START Primary Collection
# 181141  START Primary Collection
# 181219  START Primary Collection
# 181478  START Primary Collection
# 181479  START Primary Collection
#
# [2836 rows x 28 columns]

# %%
plt.subplots(figsize=(15,6))
sns.countplot('iyear',data=america,palette='RdYlGn_r',edgecolor=sns.color_palette('dark',7))
plt.xticks(rotation=90)
plt.title('Number Of Terrorist Activities Each Year in United States')
plt.show()

# %%
raw['weaptype1_txt'].unique()
# Out:
# array(['Unknown', 'Explosives', 'Incendiary', 'Firearms', 'Chemical',
#        'Melee', 'Sabotage Equipment',
#        'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)',
#        'Fake Weapons', 'Radiological', 'Other', 'Biological'],
#       dtype=object)

# %%
america.head()
# Out:
#          eventid  iyear  imonth  iday  country    country_txt  region  \
# 5   1.970010e+11   1970       1     1      217  United States       1
# 7   1.970010e+11   1970       1     2      217  United States       1
# 8   1.970010e+11   1970       1     2      217  United States       1
# 9   1.970010e+11   1970       1     3      217  United States       1
# 10  1.970010e+11   1970       1     1      217  United States       1
#
#        region_txt   provstate     city       ...          natlty1_txt  \
# 5   North America    Illinois    Cairo       ...        United States
# 7   North America  California  Oakland       ...        United States
# 8   North America   Wisconsin  Madison       ...        United States
# 9   North America   Wisconsin  Madison       ...        United States
# 10  North America   Wisconsin  Baraboo       ...        United States
#
#                               gname  \
# 5                Black Nationalists
# 7                           Unknown
# 8                   New Year's Gang
# 9                   New Year's Gang
# 10  Weather Underground, Weathermen
#
#                                             motive weaptype1_txt  \
# 5   To protest the Cairo Illinois Police Deparment      Firearms
# 7                                              NaN    Explosives
# 8      To protest the War in Vietnam and the draft    Incendiary
# 9      To protest the War in Vietnam and the draft    Incendiary
# 10                                             NaN    Explosives
#
#                                            weapdetail  \
# 5                        Several gunshots were fired.
# 7                                                 NaN
# 8                     Firebomb consisting of gasoline
# 9   Poured gasoline on the floor and lit it with a...
# 10                                          Explosive
#
#                  propextent_txt propvalue  \
# 5   Minor (likely < $1 million)       NaN
# 7   Minor (likely < $1 million)   22500.0
# 8   Minor (likely < $1 million)   60000.0
# 9   Minor (likely < $1 million)       NaN
# 10  Minor (likely < $1 million)       0.0
#
#                                           propcomment  \
# 5                                                 NaN
# 7                    Three transformers were damaged.
# 8   Basketball courts, weight room, swimming pool,...
# 9                                       Slight damage
# 10                                                NaN
#
#                                              addnotes        dbsource
# 5   The Cairo Chief of Police, William Petersen, r...  Hewitt Project
# 7   Damages were estimated to be between $20,000-$...  Hewitt Project
# 8   The New Years Gang issue a communiqu to a loc...  Hewitt Project
# 9   Karl Armstrong's girlfriend, Lynn Schultz, dro...  Hewitt Project
# 10                                                NaN            PGIS
#
# [5 rows x 28 columns]

# %%
america2017 = america[america.iyear == 2017]
america2017['weapon_count'] = america2017.groupby('weaptype1_txt')["weaptype1_txt"].transform('count')
america2017.head()
# Out:
# /Users/siyuxie/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#              eventid  iyear  imonth  iday  country    country_txt  region  \
# 170846  2.017010e+11   2017       1     2      217  United States       1
# 170951  2.017010e+11   2017       1     6      217  United States       1
# 170978  2.017010e+11   2017       1     7      217  United States       1
# 170984  2.017010e+11   2017       1     7      217  United States       1
# 171158  2.017010e+11   2017       1    14      217  United States       1
#
#            region_txt   provstate             city     ...       \
# 170846  North America    Illinois          Chicago     ...
# 170951  North America     Florida  Fort Lauderdale     ...
# 170978  North America         NaN      Hudson Bend     ...
# 170984  North America       Texas       Fort Worth     ...
# 171158  North America  Washington         Bellevue     ...
#
#                              gname  \
# 170846       Anti-White extremists
# 170951  Jihadi-inspired extremists
# 170978      Anti-Muslim extremists
# 170984                     Unknown
# 171158      Anti-Muslim extremists
#
#                                                    motive weaptype1_txt  \
# 170846  The specific motive is unknown; however, sourc...         Melee
# 170951  An unaffiliated individual, identified as Este...      Firearms
# 170978                                                NaN    Incendiary
# 170984                                                NaN    Incendiary
# 171158  The specific motive is unknown; however, sourc...    Incendiary
#
#                                    weapdetail               propextent_txt  \
# 170846                                    NaN                          NaN
# 170951  A 9-mm pistol was used in the attack.                          NaN
# 170978                                    NaN  Minor (likely < $1 million)
# 170984                                    NaN  Minor (likely < $1 million)
# 171158                                    NaN  Minor (likely < $1 million)
#
#         propvalue                           propcomment  \
# 170846        NaN                                   NaN
# 170951        NaN                                   NaN
# 170978      -99.0  A mosque was damaged in this attack.
# 170984      -99.0  A church was damaged in this attack.
# 171158      -99.0  A mosque was damaged in this attack.
#
#                                                  addnotes  \
# 170846                                                NaN
# 170951  Casualty numbers conflict across sources. Foll...
# 170978  There is doubt that this incident meets terror...
# 170984                                                NaN
# 171158  There is doubt that this incident meets terror...
#
#                         dbsource weapon_count
# 170846  START Primary Collection            7
# 170951  START Primary Collection           25
# 170978  START Primary Collection           25
# 170984  START Primary Collection           25
# 171158  START Primary Collection           25
#
# [5 rows x 29 columns]

# %%
limits = ['Unknown', 'Explosives', 'Incendiary', 'Firearms', 'Chemical',
       'Melee', 'Sabotage Equipment',
       'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)',
       'Fake Weapons', 'Radiological', 'Other', 'Biological']
colors = ["rgb(0,116,217)","rgb(255,65,54)","rgb(133,20,75)","rgb(255,133,27)","rgb(0,255,127)","rgb(135,206,250)","rgb(0,100,0)","rgb(255,215,0)","rgb(205,92,92)","rgb(255,20,147)","rgb(186,85,211)","rgb(106,90,205)"]

# %%
america2017.loc[america2017.weaptype1_txt == 'Unknown', 'color'] = 'rgb(0,116,217)'
america2017.loc[america2017.weaptype1_txt == 'Explosives', 'color'] = 'rgb(255,65,54)'
america2017.loc[america2017.weaptype1_txt == 'Incendiary', 'color'] = 'rgb(133,20,75)'
america2017.loc[america2017.weaptype1_txt == 'Firearms', 'color'] = 'rgb(255,133,27)'
america2017.loc[america2017.weaptype1_txt == 'Chemical', 'color'] = 'rgb(0,255,127)'
america2017.loc[america2017.weaptype1_txt == 'Melee', 'color'] = 'rgb(0,116,217)'
america2017.loc[america2017.weaptype1_txt == 'Sabotage Equipment', 'color'] = 'rgb(135,206,250)'
america2017.loc[america2017.weaptype1_txt == 'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)', 'color'] = 'rgb(0,100,0)'
america2017.loc[america2017.weaptype1_txt == 'Fake Weapons', 'color'] = 'rgb(255,215,0)'
america2017.loc[america2017.weaptype1_txt == 'Radiological', 'color'] = 'rgb(205,92,92)'
america2017.loc[america2017.weaptype1_txt == 'Other', 'color'] = 'rgb(255,20,147)'
america2017.loc[america2017.weaptype1_txt == 'Biological', 'color'] = 'rgb(186,85,211)'
# Out:
# /Users/siyuxie/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/siyuxie/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
len(america2017)
# Out:
# 65

# %%
activities = []
for i in range(len(america2017)):
    activity = dict(
        type = 'scattergeo',
        locationmode = 'USA-states',
        lon = america2017['longitude'],
        lat = america2017['latitude'],
        text = america2017['weaptype1_txt'],
        marker = dict(
            color = america2017['color'],
            line = dict(width=0.5, color='rgb(40,40,40)'),
            sizemode = 'area'
        ),)
    activities.append(activity)

layout = dict(
        title = 'Number Of Terrorist Activities in USA',
        showlegend = True,
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"
        ),
    )

fig = dict(data=activities, layout=layout)
py.iplot(fig, validate=False, filename='d3-bubble-map-populations')
#size = america['weaptype1_txt']/scale,
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~srveale/261.embed" height="525px" width="100%"></iframe>

# %%
america2017treemap = america2017.drop_duplicates(['weaptype1_txt'])
america2017treemap = america2017treemap.replace('Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)', 'Vehicle')

import matplotlib.pyplot as plt
import matplotlib
import squarify
cmap = matplotlib.cm.viridis

mini, maxi = america2017treemap.iday.min(), america2017treemap.iday.max()
norm = matplotlib.colors.Normalize(vmin=mini, vmax=maxi)
colors = [cmap(norm(value)) for value in america2017treemap.iday]
colors[1] = "#FBFCFE"
labels = [(label) for label in zip(america2017treemap.weaptype1_txt, america2017treemap.weapon_count)]

# make plot
fig = plt.figure(figsize=(12, 10))
fig.suptitle("USA", fontsize=20)
ax = fig.add_subplot(111, aspect="equal")
ax = squarify.plot(sizes = america2017treemap.weapon_count, label=labels, ax=ax, color = colors,alpha=.4 )
ax.set_xticks([])
ax.set_yticks([])
ax.set_title("Weapon Type vs Activity Count\n", fontsize=14)

plt.show()
